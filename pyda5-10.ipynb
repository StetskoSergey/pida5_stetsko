# %% [markdown]
# Визуализация на Python
# Домашнее задание на базе данных продаж нашей компании

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 12,9

# импортируем нужные библиотеки
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# %cd C:\Users\Stesk\Documents\GitHub\pida5_stetsko
# Out:
# C:\Users\Stesk\Documents\GitHub\pida5_stetsko

# %%
names = pd.read_csv('test.csv', sep=';', header=0)

# %%
names
# Out:
#           date amount                               Region_name  \
# 0   04.09.2019     75  Санкт-Петербург - Основное подразделение
# 1   04.09.2019     50                                    Тамбов
# 2   02.09.2019  1 500             Москва-Основное подразделение
# 3   02.09.2019    250      Ярославль-Обособленное подразделение
# 4   09.09.2019    500                                    Тамбов
# 5   02.09.2019    300  Санкт-Петербург - Основное подразделение
# 6   02.09.2019    975                                    Тамбов
# 7   02.09.2019    100      Ярославль-Обособленное подразделение
# 8   05.09.2019    500             Казань-Основное подразделение
# 9   03.09.2019    750      Дзержинск-Обособленное подразделение
# 10  05.09.2019    750     Ростов-на-Дону Основное подразделение
# 11  06.09.2019    150             Москва-Основное подразделение
# 12  04.09.2019     50                                    Тамбов
# 13  05.09.2019     25    Новосибирск-Обособленное подразделение
# ...

# %%
def parsing_date(row):
    return datetime.strptime(row.date, '%d.%m.%Y')

# %%
names['date'] = names.apply(parsing_date, axis=1)

# %%
# Out:
#          date amount                               Region_name  \
# 0  2019-09-04     75  Санкт-Петербург - Основное подразделение
# 1  2019-09-04     50                                    Тамбов
# 2  2019-09-02  1 500             Москва-Основное подразделение
# 3  2019-09-02    250      Ярославль-Обособленное подразделение
# 4  2019-09-09    500                                    Тамбов
# 5  2019-09-02    300  Санкт-Петербург - Основное подразделение
# 6  2019-09-02    975                                    Тамбов
# 7  2019-09-02    100      Ярославль-Обособленное подразделение
# 8  2019-09-05    500             Казань-Основное подразделение
# 9  2019-09-03    750      Дзержинск-Обособленное подразделение
# 10 2019-09-05    750     Ростов-на-Дону Основное подразделение
# 11 2019-09-06    150             Москва-Основное подразделение
# 12 2019-09-04     50                                    Тамбов
# 13 2019-09-05     25    Новосибирск-Обособленное подразделение
# ...

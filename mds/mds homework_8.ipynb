# %% [markdown]
# <a href="https://colab.research.google.com/github/StetskoSergey/pida5_stetsko/blob/master/mds%20homework_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задание 1
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math

# %matplotlib inline

# %%
#fig, axs = plt.subplots(ncols=5, nrows=3, figsize=(12, 10))
index = 0
axs = axs.flatten()
for k,v in data.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.show()

# %%
x = np.linspace(-5,5,100)

# %%
def norm(x, mu, sigma):
  # зададим нормально распределенную случайную величину
  norm_rv = sts.norm(loc=mu, scale=sigma)
  return norm_rv.pdf(x)

def expon(x, lam):
  expon_rv = sts.expon(lam)
  return expon_rv.pdf(x)  

def st(x, n):
  t_rv = sts.t(n)
  return t_rv.pdf(x)

# %%
x = np.linspace(-5,5,100)
plt.plot(x, norm(x,2.0,0.5))
plt.plot(x, expon(x,0.1))
plt.plot(x, st(x,10))

# %%
plt.plot(x, norm(x,2.0,2.0))
plt.plot(x, expon(x,0.5))
plt.plot(x, st(x,100))

# %%
plt.plot(x, norm(x,-2.0,1))
plt.plot(x, expon(x,2))
plt.plot(x, st(x,2))

# %%
plt.plot(x, norm(x,0.0,1))
plt.plot(x, expon(x,0.8))
plt.plot(x, st(x,2))

# %%
plt.plot(x, norm(x,0.0,3.5))
plt.plot(x, expon(x,-1))
plt.plot(x, st(x,10000))

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Непрерывная случайная величина задана плотностью распределения:
# $$ f(\xi) = C, x \in [0;5];f(\xi) = 0, x \notin [0;5]$$
# Найдите C, математическое ожидание $\xi$ а также вероятность попадания $\xi$ в отрезок $[3.5;7]$, т.е. $P(3.5<\xi<7)$.

# %% [markdown]
# равномерное распределение, площадь под кривой должа быть равна 1
# отсюда
# С = 1/5
#
# Математическое ожидание $\xi$ равно - a + b /2 = 2,5
#
# Вероятность попадания в отрезок   [3.5;7] -
# нужно проинтегрировать плотность на этом отрезке
#
# P(3.5<ξ<7) = P(3.5<ξ<=5) + P(5<ξ<7) = (5-3.5)*1/5 + 0 = 0.3

# %% [markdown]
# ### Задание 3
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
Формула Шеннона

- 1/54*log^2(1/54) - 1/4*log^2(1/4) - 1/28*log^2(1/28)

Формула Хартли

log^2(28)

# %%
-1/54*math.log2(1/54)-1/4*math.log2(1/4)-1/28*math.log2(1/28)
# Out:
# 0.7782632379971479

# %%
math.log2(28)
# Out:
# 4.807354922057604
